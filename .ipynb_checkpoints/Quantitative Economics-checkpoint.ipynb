# %% [markdown]
# # Quantitative Economics with Python

# %%
#pip install quantecon

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
error_values = np.random.randn(100)
plt.plot(error_values)
plt.xlabel('Observaciones')
plt.ylabel('Oscilaciones')
plt.show();
