# %%
#pip install Quandl

# %%
#quandl.ApiConfig.api_key = 'SaEWdymen3nJQx8H65v7'

# %%
#pip install pandas-datareader

# %%
import pandas as pd
import numpy as np
import datetime

# Gráficos

import matplotlib.pyplot as plt
# %matplotlib inline

# Quand para información financiera

import quandl

# Obtener información de SP500

quandl.ApiConfig.api_key = "SaEWdymen3nJQx8H65v7"

Quandl_code = "YALE/SPCOMP"

sp = quandl.get(Quandl_code, start_date= '1971-12-31', end_date= '2019-12-31')

# %%
sp.head()
# Out:
#             S&P Composite  Dividend  Earnings   CPI  Long Interest Rate  \
# Year
# 1971-12-31          99.17      3.07   5.70000  41.1                5.93
# 1972-01-31         103.30      3.07   5.73667  41.1                5.95
# 1972-02-29         105.20      3.07   5.77333  41.3                6.08
# 1972-03-31         107.70      3.07   5.81000  41.4                6.07
# 1972-04-30         108.80      3.07   5.86333  41.5                6.19
#
#             Real Price  Real Dividend  Real Earnings  \
# Year
# 1971-12-31  620.449504      19.207220      35.661613
# 1972-01-31  646.288533      19.207220      35.891036
# 1972-02-29  654.988446      19.114207      35.945479
# 1972-03-31  668.934065      19.068037      36.086415
# 1972-04-30  674.137908      19.022090      36.329899
#
#             Cyclically Adjusted PE Ratio
# Year
# 1971-12-31                     16.603557
# 1972-01-31                     17.262997
# 1972-02-29                     17.464148
# ...
